# %% [markdown]
# # 19CSE304 Assignment Part B
#
# KISHORE AV
# CB.EN.U4CSE20231

# %% [markdown]
# ## B (2)

# %%
bicycledata = pd.read_csv('fremont-bridge-hourly-bicycle-counts-by-month-october-2012-to-present.csv')
bicycledata
# Out:
#                           Date  Fremont Bridge Total  \
# 0      2012-10-03T00:00:00.000                  13.0
# 1      2012-10-03T01:00:00.000                  10.0
# 2      2012-10-03T02:00:00.000                   2.0
# 3      2012-10-03T03:00:00.000                   5.0
# 4      2012-10-03T04:00:00.000                   7.0
# ...                        ...                   ...
# 62035  2019-10-31T19:00:00.000                 111.0
# 62036  2019-10-31T20:00:00.000                  52.0
# 62037  2019-10-31T21:00:00.000                  41.0
# 62038  2019-10-31T22:00:00.000                  32.0
# 62039  2019-10-31T23:00:00.000                  18.0
#
#        Fremont Bridge East Sidewalk  Fremont Bridge West Sidewalk
# 0                               4.0                           9.0
# 1                               4.0                           6.0
# 2                               1.0                           1.0
# ...

# %%
bicycledata["newDate"] = pd.to_datetime(bicycledata['Date'])

# %%
bicycledata
# Out:
#                           Date  Fremont Bridge Total  \
# 0      2012-10-03T00:00:00.000                  13.0
# 1      2012-10-03T01:00:00.000                  10.0
# 2      2012-10-03T02:00:00.000                   2.0
# 3      2012-10-03T03:00:00.000                   5.0
# 4      2012-10-03T04:00:00.000                   7.0
# ...                        ...                   ...
# 62035  2019-10-31T19:00:00.000                 111.0
# 62036  2019-10-31T20:00:00.000                  52.0
# 62037  2019-10-31T21:00:00.000                  41.0
# 62038  2019-10-31T22:00:00.000                  32.0
# 62039  2019-10-31T23:00:00.000                  18.0
#
#        Fremont Bridge East Sidewalk  Fremont Bridge West Sidewalk  \
# 0                               4.0                           9.0
# 1                               4.0                           6.0
# 2                               1.0                           1.0
# ...

# %%
bicycledata.set_index('newDate', inplace= True)
tempbicycledata = bicycledata.copy()

# %%
bicycledata['2015']
# Out:
# C:\Users\sanja\AppData\Local\Temp\ipykernel_15220\3755201057.py:1: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   bicycledata['2015']
#                                         Date  Fremont Bridge Total  \
# newDate
# 2015-01-01 00:00:00  2015-01-01T00:00:00.000                  13.0
# 2015-01-01 01:00:00  2015-01-01T01:00:00.000                  27.0
# 2015-01-01 02:00:00  2015-01-01T02:00:00.000                  19.0
# 2015-01-01 03:00:00  2015-01-01T03:00:00.000                   6.0
# 2015-01-01 04:00:00  2015-01-01T04:00:00.000                   5.0
# ...                                      ...                   ...
# 2015-12-31 19:00:00  2015-12-31T19:00:00.000                  23.0
# 2015-12-31 20:00:00  2015-12-31T20:00:00.000                  12.0
# ...

# %% [markdown]
# ## Resample, shifting and windowing

# %%
monthlyData = bicycledata.resample('M').mean()
# Out:
# C:\Users\sanja\AppData\Local\Temp\ipykernel_15220\1134180626.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   monthlyData = bicycledata.resample('M').mean()

# %%
monthlyData
# Out:
#             Fremont Bridge Total  Fremont Bridge East Sidewalk  \
# newDate
# 2012-10-31             94.389368                     48.511494
# 2012-11-30             70.343056                     36.197222
# 2012-12-31             48.883065                     25.010753
# 2013-01-31             60.327957                     30.793011
# 2013-02-28             74.444940                     38.538690
# ...                          ...                           ...
# 2019-06-30            184.044444                     72.188889
# 2019-07-31            185.099462                     71.459677
# 2019-08-31            191.416667                     70.483871
# 2019-09-30            155.797222                     57.568056
# 2019-10-31            140.454301                     49.877688
#
#             Fremont Bridge West Sidewalk
# newDate
# 2012-10-31                     45.877874
# 2012-11-30                     34.145833
# 2012-12-31                     23.872312
# ...

# %%
bicycledata.shift(100)
# Out:
#                                         Date  Fremont Bridge Total  \
# newDate
# 2012-10-03 00:00:00                     None                   NaN
# 2012-10-03 01:00:00                     None                   NaN
# 2012-10-03 02:00:00                     None                   NaN
# 2012-10-03 03:00:00                     None                   NaN
# 2012-10-03 04:00:00                     None                   NaN
# ...                                      ...                   ...
# 2019-10-31 19:00:00  2019-10-27T15:00:00.000                 225.0
# 2019-10-31 20:00:00  2019-10-27T16:00:00.000                 230.0
# 2019-10-31 21:00:00  2019-10-27T17:00:00.000                 132.0
# 2019-10-31 22:00:00  2019-10-27T18:00:00.000                  70.0
# 2019-10-31 23:00:00  2019-10-27T19:00:00.000                  31.0
#
#                      Fremont Bridge East Sidewalk  \
# newDate
# 2012-10-03 00:00:00                           NaN
# ...

# %%
rolling = bicycledata.rolling(10, center=True).sum()
# Out:
# C:\Users\sanja\AppData\Local\Temp\ipykernel_15220\60025146.py:1: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were Index(['Date'], dtype='object')
#   rolling = bicycledata.rolling(10, center=True).sum()

# %%
rolling.head(30)
# Out:
#                      Fremont Bridge Total  Fremont Bridge East Sidewalk  \
# newDate
# 2012-10-03 00:00:00                   NaN                           NaN
# 2012-10-03 01:00:00                   NaN                           NaN
# 2012-10-03 02:00:00                   NaN                           NaN
# 2012-10-03 03:00:00                   NaN                           NaN
# 2012-10-03 04:00:00                   NaN                           NaN
# 2012-10-03 05:00:00                1288.0                         863.0
# 2012-10-03 06:00:00                1393.0                         931.0
# 2012-10-03 07:00:00                1425.0                         937.0
# 2012-10-03 08:00:00                1499.0                         971.0
# 2012-10-03 09:00:00                1584.0                        1011.0
# 2012-10-03 10:00:00                1705.0                        1082.0
# 2012-10-03 11:00:00                1838.0                        1133.0
# ...

# %% [markdown]
# ## Visualization

# %% [markdown]
# import matplotlib.pyplot as plt
# import seaborn
# cop

# %%
tempbicycledata.plot()
# Out:
# <AxesSubplot: xlabel='newDate'>

# %%
weekly = tempbicycledata.resample('W').sum()
weekly
# Out:
# C:\Users\sanja\AppData\Local\Temp\ipykernel_15220\2891122431.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   weekly = tempbicycledata.resample('W').sum()
#             Fremont Bridge Total  Fremont Bridge East Sidewalk  \
# newDate
# 2012-10-07               14292.0                        7297.0
# 2012-10-14               16795.0                        8679.0
# 2012-10-21               15509.0                        7946.0
# 2012-10-28               13437.0                        6901.0
# 2012-11-04               12194.0                        6408.0
# ...                          ...                           ...
# 2019-10-06               27270.0                        9785.0
# 2019-10-13               23495.0                        8543.0
# ...

# %%
weekly.plot()
# Out:
# <AxesSubplot: xlabel='newDate'>

# %% [markdown]
# ## B (3)

# %%
path = 'https://raw.githubusercontent.com/wangruinju/python-for-data-analysis/master/pydata-book-2nd-edition/examples/stock_px_2.csv'

# %%
stocksdata = pd.read_csv(path)

# %%
stocksdata
stocksdata["Unnamed: 0"] = pd.to_datetime(stocksdata['Unnamed: 0'])

# %% [markdown]
# ## Indexing

# %%
stocksdata[10:20]
# Out:
#    Unnamed: 0  AAPL   MSFT    XOM     SPX
# 10 2003-01-16  7.31  21.75  28.90  914.60
# 11 2003-01-17  7.05  20.22  28.60  901.78
# 12 2003-01-21  7.01  20.17  27.94  887.62
# 13 2003-01-22  6.94  20.04  27.58  878.36
# 14 2003-01-23  7.09  20.54  27.52  887.34
# 15 2003-01-24  6.90  19.59  26.93  861.40
# 16 2003-01-27  7.07  19.32  26.21  847.48
# 17 2003-01-28  7.29  19.18  26.90  858.54
# 18 2003-01-29  7.47  19.61  27.88  864.36
# 19 2003-01-30  7.16  18.95  27.37  844.61

# %%
stocksdata.set_index('Unnamed: 0',inplace=True)

# %%
stocksdata['AAPL'][0:10]
# Out:
# Unnamed: 0
# 2003-01-02    7.40
# 2003-01-03    7.45
# 2003-01-06    7.45
# 2003-01-07    7.43
# 2003-01-08    7.28
# 2003-01-09    7.34
# 2003-01-10    7.36
# 2003-01-13    7.32
# 2003-01-14    7.30
# 2003-01-15    7.22
# Name: AAPL, dtype: float64

# %% [markdown]
# # Selection

# %%
stocksdata['AAPL']
# Out:
# Unnamed: 0
# 2003-01-02      7.40
# 2003-01-03      7.45
# 2003-01-06      7.45
# 2003-01-07      7.43
# 2003-01-08      7.28
#                ...
# 2011-10-10    388.81
# 2011-10-11    400.29
# 2011-10-12    402.19
# 2011-10-13    408.43
# 2011-10-14    422.00
# Name: AAPL, Length: 2214, dtype: float64

# %%
stocksdata[['MSFT','XOM']]
# Out:
#              MSFT    XOM
# Unnamed: 0
# 2003-01-02  21.11  29.22
# 2003-01-03  21.14  29.24
# 2003-01-06  21.52  29.96
# 2003-01-07  21.93  28.95
# 2003-01-08  21.31  28.83
# ...           ...    ...
# 2011-10-10  26.94  76.28
# 2011-10-11  27.00  76.27
# 2011-10-12  26.96  77.16
# 2011-10-13  27.18  76.37
# 2011-10-14  27.27  78.11
#
# [2214 rows x 2 columns]

# %%
stocksdata[stocksdata['AAPL'] > 20]
# Out:
#               AAPL   MSFT    XOM      SPX
# Unnamed: 0
# 2004-10-06   20.32  22.69  43.16  1142.05
# 2004-10-14   22.49  22.10  42.02  1103.29
# 2004-10-15   22.75  22.26  42.29  1108.20
# 2004-10-18   23.88  22.59  42.06  1114.02
# 2004-10-19   23.71  22.41  41.68  1103.23
# ...            ...    ...    ...      ...
# 2011-10-10  388.81  26.94  76.28  1194.89
# 2011-10-11  400.29  27.00  76.27  1195.54
# 2011-10-12  402.19  26.96  77.16  1207.25
# 2011-10-13  408.43  27.18  76.37  1203.66
# 2011-10-14  422.00  27.27  78.11  1224.58
#
# [1766 rows x 4 columns]

# %% [markdown]
# # Subsetting

# %%
stocksdata.iloc[0:2]
# Out:
#             AAPL   MSFT    XOM     SPX
# Unnamed: 0
# 2003-01-02  7.40  21.11  29.22  909.03
# 2003-01-03  7.45  21.14  29.24  908.59

# %% [markdown]
# # Date Ranges

# %%
stocksdata['2003':'2005']
# Out:
#              AAPL   MSFT    XOM      SPX
# Unnamed: 0
# 2003-01-02   7.40  21.11  29.22   909.03
# 2003-01-03   7.45  21.14  29.24   908.59
# 2003-01-06   7.45  21.52  29.96   929.01
# 2003-01-07   7.43  21.93  28.95   922.93
# 2003-01-08   7.28  21.31  28.83   909.93
# ...           ...    ...    ...      ...
# 2005-12-23  73.35  23.90  50.53  1268.66
# 2005-12-27  74.23  23.74  49.44  1256.54
# 2005-12-28  73.57  23.67  49.77  1258.17
# 2005-12-29  71.45  23.57  49.76  1254.42
# 2005-12-30  71.89  23.46  49.70  1248.29
#
# [756 rows x 4 columns]

# %% [markdown]
# ## Frequencies

# %%
stocksdata.value_counts()
# Out:
# AAPL    MSFT   XOM    SPX
# 6.56    20.10  29.05  893.58     1
# 156.66  23.64  73.75  1260.31    1
# 154.50  27.11  84.92  1531.38    1
# 154.55  26.95  82.47  1360.55    1
# 155.64  29.48  75.61  1310.50    1
#                                 ..
# 57.59   22.99  49.42  1207.01    1
# 57.56   19.97  52.57  1251.54    1
# 57.50   23.22  49.65  1202.76    1
# 57.47   20.38  51.31  1240.12    1
# 422.00  27.27  78.11  1224.58    1
# Length: 2214, dtype: int64

# %% [markdown]
# ## Shifting

# %%
temp_df = stocksdata.shift(100)

# %%
temp_df
# Out:
#               AAPL   MSFT    XOM      SPX
# Unnamed: 0
# 2003-01-02     NaN    NaN    NaN      NaN
# 2003-01-03     NaN    NaN    NaN      NaN
# 2003-01-06     NaN    NaN    NaN      NaN
# 2003-01-07     NaN    NaN    NaN      NaN
# 2003-01-08     NaN    NaN    NaN      NaN
# ...            ...    ...    ...      ...
# 2011-10-10  339.87  24.54  81.20  1340.68
# 2011-10-11  340.53  24.56  81.79  1343.60
# 2011-10-12  335.22  24.34  81.03  1333.27
# 2011-10-13  334.40  24.02  80.14  1317.37
# 2011-10-14  332.19  24.00  80.76  1316.28
#
# [2214 rows x 4 columns]

# %% [markdown]
# ## Time Zone Localization and Conversion

# %%
dates = stocksdata.tz_localize('US/Eastern')
dates
# Out:
#                              AAPL   MSFT    XOM      SPX
# Unnamed: 0
# 2003-01-02 00:00:00-05:00    7.40  21.11  29.22   909.03
# 2003-01-03 00:00:00-05:00    7.45  21.14  29.24   908.59
# 2003-01-06 00:00:00-05:00    7.45  21.52  29.96   929.01
# 2003-01-07 00:00:00-05:00    7.43  21.93  28.95   922.93
# 2003-01-08 00:00:00-05:00    7.28  21.31  28.83   909.93
# ...                           ...    ...    ...      ...
# 2011-10-10 00:00:00-04:00  388.81  26.94  76.28  1194.89
# 2011-10-11 00:00:00-04:00  400.29  27.00  76.27  1195.54
# 2011-10-12 00:00:00-04:00  402.19  26.96  77.16  1207.25
# 2011-10-13 00:00:00-04:00  408.43  27.18  76.37  1203.66
# 2011-10-14 00:00:00-04:00  422.00  27.27  78.11  1224.58
#
# [2214 rows x 4 columns]

# %% [markdown]
# ## Periods and Period Arithmetic

# %%
dates.index = pd.PeriodIndex(stocksdata.index, freq='M')

# %%
dates
# Out:
#               AAPL   MSFT    XOM      SPX
# Unnamed: 0
# 2003-01       7.40  21.11  29.22   909.03
# 2003-01       7.45  21.14  29.24   908.59
# 2003-01       7.45  21.52  29.96   929.01
# 2003-01       7.43  21.93  28.95   922.93
# 2003-01       7.28  21.31  28.83   909.93
# ...            ...    ...    ...      ...
# 2011-10     388.81  26.94  76.28  1194.89
# 2011-10     400.29  27.00  76.27  1195.54
# 2011-10     402.19  26.96  77.16  1207.25
# 2011-10     408.43  27.18  76.37  1203.66
# 2011-10     422.00  27.27  78.11  1224.58
#
# [2214 rows x 4 columns]

# %%
dates.index + 12
# Out:
# PeriodIndex(['2004-01', '2004-01', '2004-01', '2004-01', '2004-01', '2004-01',
#              '2004-01', '2004-01', '2004-01', '2004-01',
#              ...
#              '2012-10', '2012-10', '2012-10', '2012-10', '2012-10', '2012-10',
#              '2012-10', '2012-10', '2012-10', '2012-10'],
#             dtype='period[M]', name='Unnamed: 0', length=2214)

# %% [markdown]
# ## Period Frequency Conversion

# %%
index = pd.PeriodIndex(dates.index, freq='M')
index = index.asfreq('Q')

# %%
index
# Out:
# PeriodIndex(['2003Q1', '2003Q1', '2003Q1', '2003Q1', '2003Q1', '2003Q1',
#              '2003Q1', '2003Q1', '2003Q1', '2003Q1',
#              ...
#              '2011Q4', '2011Q4', '2011Q4', '2011Q4', '2011Q4', '2011Q4',
#              '2011Q4', '2011Q4', '2011Q4', '2011Q4'],
#             dtype='period[Q-DEC]', name='Unnamed: 0', length=2214)

# %% [markdown]
# ## Resampling and Frequency Conversion

# %%
#path = 'https://raw.githubusercontent.com/wangruinju/python-for-data-analysis/master/pydata-book-2nd-edition/examples/stock_px_2.csv'
df = pd.read_csv(path)
Dates = df["Unnamed: 0"]
df["Unnamed: 0"] = pd.to_datetime(Dates)
df = df.set_index('Unnamed: 0')
df_monthly = df['AAPL'].resample('M').mean()
df_monthly
# Out:
# Unnamed: 0
# 2003-01-31      7.239048
# 2003-02-28      7.333684
# 2003-03-31      7.299048
# 2003-04-30      6.923810
# 2003-05-31      8.885238
#                  ...
# 2011-06-30    331.081364
# 2011-07-31    372.238000
# 2011-08-31    376.762609
# 2011-09-30    392.493333
# 2011-10-31    389.424000
# Freq: M, Name: AAPL, Length: 106, dtype: float64

# %% [markdown]
# ## Downsampling and Upsampling

# %%
df_monthly = df['AAPL'].resample('M').mean()
df_monthly
# Out:
# Unnamed: 0
# 2003-01-31      7.239048
# 2003-02-28      7.333684
# 2003-03-31      7.299048
# 2003-04-30      6.923810
# 2003-05-31      8.885238
#                  ...
# 2011-06-30    331.081364
# 2011-07-31    372.238000
# 2011-08-31    376.762609
# 2011-09-30    392.493333
# 2011-10-31    389.424000
# Freq: M, Name: AAPL, Length: 106, dtype: float64

# %%
df_daily = df['AAPL'].resample('D').interpolate()
df_daily
# Out:
# Unnamed: 0
# 2003-01-02      7.40
# 2003-01-03      7.45
# 2003-01-04      7.45
# 2003-01-05      7.45
# 2003-01-06      7.45
#                ...
# 2011-10-10    388.81
# 2011-10-11    400.29
# 2011-10-12    402.19
# 2011-10-13    408.43
# 2011-10-14    422.00
# Freq: D, Name: AAPL, Length: 3208, dtype: float64

# %% [markdown]
# ## Moving Window Functions

# %%
df_rolling = df['XOM'].rolling(10).mean()
df_rolling
# Out:
# Unnamed: 0
# 2003-01-02       NaN
# 2003-01-03       NaN
# 2003-01-06       NaN
# 2003-01-07       NaN
# 2003-01-08       NaN
#                ...
# 2011-10-10    73.315
# 2011-10-11    73.651
# 2011-10-12    74.160
# 2011-10-13    74.409
# 2011-10-14    74.957
# Name: XOM, Length: 2214, dtype: float64

# %% [markdown]
# ## Exponentially Weighted Functions

# %%
df_ewm = df['XOM'].ewm(span=3).mean()

# %%
df_ewm
# Out:
# Unnamed: 0
# 2003-01-02    29.220000
# 2003-01-03    29.233333
# 2003-01-06    29.648571
# 2003-01-07    29.276000
# 2003-01-08    29.045806
#                 ...
# 2011-10-10    74.913055
# 2011-10-11    75.591528
# 2011-10-12    76.375764
# 2011-10-13    76.372882
# 2011-10-14    77.241441
# Name: XOM, Length: 2214, dtype: float64

# %%
df_ewm = df['XOM'].ewm(halflife=5).mean()

# %%
df_ewm
# Out:
# Unnamed: 0
# 2003-01-02    29.220000
# 2003-01-03    29.230692
# 2003-01-06    29.508163
# 2003-01-07    29.338414
# 2003-01-08    29.206786
#                 ...
# 2011-10-10    73.267695
# 2011-10-11    73.656342
# 2011-10-12    74.109888
# 2011-10-13    74.402459
# 2011-10-14    74.882398
# Name: XOM, Length: 2214, dtype: float64
